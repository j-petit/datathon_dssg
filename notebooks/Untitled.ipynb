# %%
import boto3
import pandas as pd
df = pd.read_csv('s3://adfc-bike-census/Rostock_1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-9d948fad5876> in <module>
#       1 import boto3
#       2 import pandas as pd
# ----> 3 df = pd.read_csv('s3://adfc-bike-census/Rostock_1.csv')
#
# ...

# %%
def Berufsverkehr(df):
    beruf = df[(df['date'].dt.weekday<5)&(5<df['date'].dt.hour<10)]

# %%
def Freizeit(df,start,stop,weekday):
    freizeit =  df[(df['date'].dt.weekday<weekday)&(start<df['date'].dt.hour<stop)]
