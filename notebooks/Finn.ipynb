# %%
import pandas as pd
from finn_jo_jo import *
df = read_stations()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895943 entries, 0 to 10895942
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   city          object
#  1   station_code  int64
#  2   date          datetime64[ns]
#  3   count         int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 332.5+ MB
#        station_code         count
# count  1.089594e+07  1.089594e+07
# mean   5.931304e+00  2.204344e+01
# std    4.538523e+00  3.381662e+01
# min    1.000000e+00  0.000000e+00
# 25%    2.000000e+00  1.000000e+00
# 50%    5.000000e+00  8.000000e+00
# 75%    9.000000e+00  2.900000e+01
# max    1.800000e+01  2.047000e+03

# %%
piv = to_pivot(df)
piv.resample('H').sum()
# Out:
# city                Aschaffenburg Berlin                                    \
# station_code                   1      1      2      3      4      5     6
# date
# 2016-01-01 00:00:00           0.0    7.0    7.0    0.0    0.0    4.0   0.0
# 2016-01-01 01:00:00           0.0   11.0   15.0    0.0    0.0    5.0   0.0
# 2016-01-01 02:00:00           0.0   21.0   15.0    0.0    0.0    6.0   0.0
# 2016-01-01 03:00:00           0.0   17.0    9.0    0.0    0.0    6.0   0.0
# 2016-01-01 04:00:00           0.0   12.0   17.0    0.0    0.0    4.0   0.0
# ...                           ...    ...    ...    ...    ...    ...   ...
# 2021-09-29 19:00:00          53.0  328.0  408.0  217.0  376.0  181.0  73.0
# 2021-09-29 20:00:00          27.0  204.0  289.0  122.0  207.0   85.0  43.0
# 2021-09-29 21:00:00          10.0  146.0  201.0   61.0  160.0   59.0  41.0
# 2021-09-29 22:00:00          17.0  147.0  163.0   57.0   95.0   29.0  38.0
# ...

# %%
plot_city_time('Rostock')
