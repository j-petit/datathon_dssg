# %%
import pandas as pd
from finn import *
df = read_stations()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895943 entries, 0 to 10895942
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   city          object
#  1   station_code  int64
#  2   date          datetime64[ns]
#  3   count         int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 332.5+ MB
#        station_code         count
# count  1.089594e+07  1.089594e+07
# mean   5.931304e+00  2.204344e+01
# std    4.538523e+00  3.381662e+01
# min    1.000000e+00  0.000000e+00
# 25%    2.000000e+00  1.000000e+00
# 50%    5.000000e+00  8.000000e+00
# 75%    9.000000e+00  2.900000e+01
# max    1.800000e+01  2.047000e+03

# %% [markdown]
# # Plots für Berlin

# %%
from finn import *
plot_city_time('Berlin')

# %% [markdown]
# # Aggregating Data for Berlin

# %%
berlin = df.loc[df['city'] == 'Berlin']
berlin_piv = to_pivot(berlin)
berlin_piv.groupby(df.index / 3).sum()
#berlin_piv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-ebcb1b3cbb1f> in <module>
#       1 berlin = df.loc[df['city'] == 'Berlin']
#       2 berlin_piv = to_pivot(berlin)
# ----> 3 berlin_piv.index.hour.head()
#       4 #berlin_piv
#
# AttributeError: 'Int64Index' object has no attribute 'head'

# %%
col1 = pd.DataFrame([2,1,3,1,0,5,2,3])
col1
col2 = col1.groupby(col1.index == 0 & 3).sum()
col2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-18ec65283f8b> in <module>
#       1 col1 = pd.DataFrame([2,1,3,1,0,5,2,3])
#       2 col1
# ----> 3 col2 = col1.groupby(col1.index == 0 & col1.index == 3).sum()
#       4 col2
#
# TypeError: unsupported operand type(s) for &: 'int' and 'RangeIndex'

# %%
berlin.loc[berlin['datum']] = berlin['date'].dt.date
berlin.loc['hour'] = berlin['date'].dt.hour
berlin
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-8e48155b9b86> in <module>
# ...

# %%
#berlin = berlin[(berlin['datum'] >= '01/01/2018') & (berlin['datum'] <= '31/12/2020' )]
#berlin
berlin

berlin['datum'].dtypes
# Out:
# dtype('O')

# %%
berlin_grouped = berlin.groupby([berlin['datum'] , berlin['hour'], berlin['station_code']], as_index=False)['count'].sum()
berlin_grouped

# df[(df < 3) | (df == 5)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-497469594774> in <module>
# ----> 1 berlin_grouped = berlin.groupby([(berlin['datum'] > "2017/01/01") & (berlin['datum']< "2020/12/31") , berlin['hour'], berlin['station_code']], as_index=False)['count'].sum()
#       2 berlin_grouped
#       3
#       4 # df[(df < 3) | (df == 5)]
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
# ...

# %% [markdown]
# # Sortierung nach Wochentag

# %%
berlin = df_pivoted[df_pivoted['city'] == 'Berlin']
#berlin = city.groupby(city.index.hour).sum().plot(kind='bar',subplots=True, sharey=False,layout=layout, figsize=plotsize, title=f"{name}s count per hour of the day")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-0331d28dd362> in <module>
# ...
