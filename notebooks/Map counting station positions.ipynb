# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
import datetime

# %%
df = pd.read_csv('s3://adfc-bike-census/adfc_data/fetched_eco_bike_data.csv')

# %%
df_berlin = df.query('city == "Berlin"')

# %%
latlong = df_berlin[['latitude', 'longitude']]

# %%
df_berlin
# Out:
#       city  number   latitude  longitude    id_list  Distance to center [km]  \
# 1   Berlin       1  52.514066  13.417751  100024661                   1.9827
# 2   Berlin       2  52.527180  13.372020  100032152                   1.6032
# 3   Berlin       3  52.513739  13.474367  100032154                   5.7977
# 4   Berlin       4  52.566810  13.412170  100032155                   5.7547
# 5   Berlin       5  52.548840  13.400370  100032159                   3.6211
# 6   Berlin       6  52.533665  13.198963  100032161                  12.9793
# 7   Berlin       7  52.466760  13.309160  100032163                   7.7698
# 8   Berlin       8  52.488120  13.369790  100032165                   3.4648
# 9   Berlin       9  52.558190  13.364940  100032169                   4.8536
# 10  Berlin      10  52.493118  13.429149  100032236                   3.8091
# 11  Berlin      11  52.457758  13.519360  100032237                  11.0239
# ...

# %%
m = folium.Map(location=[df_berlin.iloc[0]['latitude'], df_berlin.iloc[0]['longitude']])

for index, row in df_berlin.iterrows():
    folium.Circle(
        [row['latitude'], row['longitude']], radius=40
    ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df_berlin_count['date'] = pd.to_datetime(df_berlin_count['date'])
df_berlin_count = df_berlin_count.set_index('date')
df_berlin_count.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9040658f562b> in <module>
# ----> 1 df_berlin_count['date'] = pd.to_datetime(df_berlin_count['date'])
#       2 df_berlin_count = df_berlin_count.set_index('date')
#       3 df_berlin_count.head()
#
# NameError: name 'df_berlin_count' is not defined

# %%
# Count number of bikes per day
df_berlin_count['type'] = 'spotting'
df_sum_year = df_berlin_count.pivot_table('comptage', 
                            index = [df_berlin_count.index.year], 
                            # columns = 'type', 
                            aggfunc='sum').reset_index()

df_sum_year.iloc[0].comptage
